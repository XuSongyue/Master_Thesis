# %%
import os
import re
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.mask import mask
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from torch.utils.data import TensorDataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
import logging

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Set global font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Constant definitions
PROJECTED_CRS = "EPSG:32651"  # UTM Zone 51N

# File paths
lst_dir = "shanghai_LST/LST"
boundary_path = "OSMB-a05454319b28f099ff3da3a49c5dd21e484d8b2d.geojson"
output_dir = "Results"
processed_dir = "processed_data"

# %%
# Ensure output directory and processed data directory exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(processed_dir, exist_ok=True)

# Check file existence
def check_file_exists(file_path):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File {file_path} does not exist")
    return file_path

# %%
# Load Shanghai boundary
boundary_save_path = os.path.join(processed_dir, "shanghai_boundary.geojson")
if os.path.exists(boundary_save_path):
    gdf_shanghai = gpd.read_file(boundary_save_path)
else:
    gdf_shanghai = gpd.read_file(check_file_exists(boundary_path))
    gdf_shanghai.to_file(boundary_save_path, driver="GeoJSON")

# %%
# Read and clip raster data
def read_raster(file_path, boundary):
    """Read and clip raster data, return data and metadata"""
    with rasterio.open(file_path) as src:
        out_image, out_transform = mask(src, [boundary], crop=True)
        out_meta = src.meta.copy()
        out_meta.update({'height': out_image.shape[1], 'width': out_image.shape[2], 'transform': out_transform})
        out_image = out_image.astype(np.float32)
        out_image[out_image == src.nodata] = np.nan
    return out_image[0], out_meta

# %%
# Data loading and preprocessing with flexible filename parsing
lst_data = []
skipped_files = 0
for year in range(2000, 2025):
    year_dir = os.path.join(lst_dir, str(year))
    if os.path.exists(year_dir):
        for filename in os.listdir(year_dir):
            if filename.endswith(".tif"):
                # Use regex to match both "LST_DayYYYY_MM.tif", "LST_DayYYYY-MM.tif", "LST_DayYYYY-M.tif", and case variations
                match = re.match(r"LST_Day(\d{4})[-_](\d{1,2})\.tif$", filename, re.IGNORECASE)
                if match:
                    year = int(match.group(1))
                    month = int(match.group(2))
                    if month < 1 or month > 12:
                        logger.warning(f"Invalid month value {month} in file {filename}, skipping")
                        continue
                    file_path = os.path.join(year_dir, filename)
                    lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
                    lst_mean = np.nanmean(lst)
                    if np.isnan(lst_mean):
                        logger.warning(f"LST data in file {filename} is entirely NaN, skipping")
                        skipped_files += 1
                        continue
                    lst_data.append((year, month, lst_mean))
                    logger.info(f"Loaded file: {filename}, Average LST: {lst_mean:.2f}")
                else:
                    logger.warning(f"Skipping invalid filename: {filename}")
logger.info(f"Total files skipped due to NaN: {skipped_files}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_10.tif, Average LST: 26.24
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_11.tif, Average LST: 15.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_12.tif, Average LST: 11.81
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_2.tif, Average LST: 12.52
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_3.tif, Average LST: 16.33
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_4.tif, Average LST: 20.53
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_5.tif, Average LST: 28.75
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_6.tif, Average LST: 29.41
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_7.tif, Average LST: 31.84
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_8.tif, Average LST: 29.42
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2000_9.tif, Average LST: 27.15
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_1.tif, Average LST: 8.03
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_10.tif, Average LST: 24.05
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_11.tif, Average LST: 17.70
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_12.tif, Average LST: 7.89
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_2.tif, Average LST: 11.52
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_3.tif, Average LST: 18.56
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_4.tif, Average LST: 22.53
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_5.tif, Average LST: 27.22
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_6.tif, Average LST: 28.03
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_7.tif, Average LST: 31.75
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_8.tif, Average LST: 28.62
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2001_9.tif, Average LST: 27.44
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_1.tif, Average LST: 10.52
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_10.tif, Average LST: 22.66
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_11.tif, Average LST: 16.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_12.tif, Average LST: 6.76
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_2.tif, Average LST: 13.51
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_3.tif, Average LST: 19.27
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_4.tif, Average LST: 24.70
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_5.tif, Average LST: 27.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_6.tif, Average LST: 30.99
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_7.tif, Average LST: 32.10
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_8.tif, Average LST: 31.36
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2002_9.tif, Average LST: 26.78
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_1.tif, Average LST: 7.39
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_10.tif, Average LST: 23.85
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_11.tif, Average LST: 18.59
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_12.tif, Average LST: 9.78
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_2.tif, Average LST: 10.73
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_3.tif, Average LST: 18.36
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_4.tif, Average LST: 23.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_5.tif, Average LST: 28.00
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_6.tif, Average LST: 31.66
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_7.tif, Average LST: 32.92
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_8.tif, Average LST: 32.37
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2003_9.tif, Average LST: 30.07
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_1.tif, Average LST: 7.24
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_10.tif, Average LST: 25.10
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_11.tif, Average LST: 17.19
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_12.tif, Average LST: 10.70
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_2.tif, Average LST: 13.52
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_3.tif, Average LST: 17.28
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_4.tif, Average LST: 23.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_5.tif, Average LST: 27.45
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_6.tif, Average LST: 31.07
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_7.tif, Average LST: 32.41
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_8.tif, Average LST: 31.50
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2004_9.tif, Average LST: 26.56
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_1.tif, Average LST: 7.20
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_10.tif, Average LST: 24.99
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_11.tif, Average LST: 18.53
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_12.tif, Average LST: 6.64
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_2.tif, Average LST: 9.74
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_3.tif, Average LST: 17.37
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_4.tif, Average LST: 26.54
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_5.tif, Average LST: 28.54
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_6.tif, Average LST: 34.29
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_7.tif, Average LST: 33.21
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_8.tif, Average LST: 31.59
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2005_9.tif, Average LST: 28.89
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_1.tif, Average LST: 8.37
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_10.tif, Average LST: 26.72
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_11.tif, Average LST: 18.67
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_12.tif, Average LST: 9.96
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_2.tif, Average LST: 11.46
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_3.tif, Average LST: 18.43
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_4.tif, Average LST: 21.35
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_5.tif, Average LST: 26.18
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_6.tif, Average LST: 30.40
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_7.tif, Average LST: 32.64
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_8.tif, Average LST: 32.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2006_9.tif, Average LST: 27.76
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_1.tif, Average LST: 7.49
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_10.tif, Average LST: 23.53
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_11.tif, Average LST: 18.11
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_12.tif, Average LST: 9.39
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_2.tif, Average LST: 14.82
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_3.tif, Average LST: 18.41
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_4.tif, Average LST: 23.30
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_5.tif, Average LST: 28.67
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_6.tif, Average LST: 31.19
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_7.tif, Average LST: 33.48
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_8.tif, Average LST: 31.71
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2007_9.tif, Average LST: 29.66
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_1.tif, Average LST: 6.25
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_10.tif, Average LST: 24.97
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_11.tif, Average LST: 15.45
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_12.tif, Average LST: 10.77
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_2.tif, Average LST: 10.14
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_3.tif, Average LST: 20.08
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_4.tif, Average LST: 23.27
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_5.tif, Average LST: 27.87
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_6.tif, Average LST: 30.10
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_7.tif, Average LST: 34.06
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_8.tif, Average LST: 30.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2008_9.tif, Average LST: 28.27
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_1.tif, Average LST: 6.51
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_10.tif, Average LST: 25.55
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_11.tif, Average LST: 17.23
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_12.tif, Average LST: 8.75
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_2.tif, Average LST: 18.08
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_3.tif, Average LST: 17.15
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_4.tif, Average LST: 23.75
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_5.tif, Average LST: 31.19
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_6.tif, Average LST: 32.04
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_7.tif, Average LST: 32.68
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_8.tif, Average LST: 32.21
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2009_9.tif, Average LST: 28.64
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_1.tif, Average LST: 8.20
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_10.tif, Average LST: 22.51
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_11.tif, Average LST: 18.11
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_12.tif, Average LST: 10.36
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_2.tif, Average LST: 12.14
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_3.tif, Average LST: 16.26
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_4.tif, Average LST: 19.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_5.tif, Average LST: 28.04
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_6.tif, Average LST: 32.25
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_7.tif, Average LST: 33.09
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_8.tif, Average LST: 32.09
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2010_9.tif, Average LST: 30.65
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_1.tif, Average LST: 5.64
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_10.tif, Average LST: 24.55
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_11.tif, Average LST: 18.62
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_12.tif, Average LST: 8.22
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_2.tif, Average LST: 12.67
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_3.tif, Average LST: 17.79
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_4.tif, Average LST: 25.22
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_5.tif, Average LST: 30.75
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_6.tif, Average LST: 31.73
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_7.tif, Average LST: 34.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_8.tif, Average LST: 31.35
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2011_9.tif, Average LST: 29.25
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_1.tif, Average LST: 8.31
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_10.tif, Average LST: 24.70
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_11.tif, Average LST: 15.23
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_12.tif, Average LST: 7.29
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_2.tif, Average LST: 8.87
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_3.tif, Average LST: 16.91
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_4.tif, Average LST: 23.99
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_5.tif, Average LST: 30.00
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_6.tif, Average LST: 32.62
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_7.tif, Average LST: 33.71
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_8.tif, Average LST: 32.06
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2012_9.tif, Average LST: 27.45
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_1.tif, Average LST: 8.65
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_10.tif, Average LST: 24.93
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_11.tif, Average LST: 17.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_12.tif, Average LST: 9.46
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_2.tif, Average LST: 12.85
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_3.tif, Average LST: 19.49
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_4.tif, Average LST: 24.01
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_5.tif, Average LST: 30.19
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2013_6.tif, Average LST: 29.91
# ...
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_3.tif, Average LST: 20.58
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_4.tif, Average LST: 24.60
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_5.tif, Average LST: 30.99
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_6.tif, Average LST: 31.87
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_7.tif, Average LST: 33.31
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_8.tif, Average LST: 33.72
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2020_9.tif, Average LST: 29.04
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_1.tif, Average LST: 9.71
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_10.tif, Average LST: 23.61
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_11.tif, Average LST: 16.31
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_12.tif, Average LST: 12.01
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_2.tif, Average LST: 15.38
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_3.tif, Average LST: 21.31
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_4.tif, Average LST: 25.35
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_5.tif, Average LST: 30.37
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_6.tif, Average LST: 33.49
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_7.tif, Average LST: 32.24
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_8.tif, Average LST: 32.51
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2021_9.tif, Average LST: 31.06
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_1.tif, Average LST: 10.64
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_10.tif, Average LST: 21.24
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_11.tif, Average LST: 22.05
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_12.tif, Average LST: 9.91
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_2.tif, Average LST: 12.91
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_3.tif, Average LST: 21.44
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_4.tif, Average LST: 26.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_5.tif, Average LST: 29.13
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_6.tif, Average LST: 33.01
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_7.tif, Average LST: 34.33
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_8.tif, Average LST: 35.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_day2022_9.tif, Average LST: 29.08
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-1.tif, Average LST: 10.14
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-10.tif, Average LST: 25.56
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-11.tif, Average LST: 19.23
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-12.tif, Average LST: 9.49
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-2.tif, Average LST: 12.98
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-3.tif, Average LST: 19.99
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-4.tif, Average LST: 24.13
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-5.tif, Average LST: 29.20
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-6.tif, Average LST: 32.14
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-7.tif, Average LST: 33.73
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-8.tif, Average LST: 32.93
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2023-9.tif, Average LST: 30.61
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-1.tif, Average LST: 9.02
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-10.tif, Average LST: 23.37
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-11.tif, Average LST: 16.88
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-12.tif, Average LST: 9.68
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-2.tif, Average LST: 14.32
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-3.tif, Average LST: 16.43
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-4.tif, Average LST: 23.23
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-5.tif, Average LST: 27.87
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-6.tif, Average LST: 28.67
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-7.tif, Average LST: 32.50
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-8.tif, Average LST: 34.02
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\733855072.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   lst, _ = read_raster(file_path, gdf_shanghai.unary_union)
# INFO:__main__:Loaded file: LST_Day2024-9.tif, Average LST: 29.76
# INFO:__main__:Total files skipped due to NaN: 0

# %%
# Create time series data
ts_data = pd.DataFrame(lst_data, columns=['year', 'month', 'lst'])
ts_data['datetime'] = pd.to_datetime(ts_data[['year', 'month']].assign(day=1))
initial_count = len(ts_data)
ts_data = ts_data.sort_values('datetime').drop_duplicates(subset='datetime', keep='first')
logger.info(f"Removed {initial_count - len(ts_data)} duplicate timestamps")
# Out:
# INFO:__main__:Removed 0 duplicate timestamps

# %%
# Fill missing months
all_dates = pd.date_range(start='2000-01-01', end='2024-12-01', freq='MS')
ts_data_full = pd.DataFrame(all_dates, columns=['datetime'])
ts_data_full = ts_data_full.merge(ts_data, on='datetime', how='left')
missing_before = ts_data_full['lst'].isna().sum()
ts_data_full['lst'] = ts_data_full['lst'].interpolate(method='linear')
if ts_data_full['lst'].isna().any():
    logger.warning("NaN values remain after interpolation, filling with nearest values")
    ts_data_full['lst'] = ts_data_full['lst'].fillna(method='ffill').fillna(method='bfill')
logger.info(f"Interpolated {missing_before} missing values")
ts_data = ts_data_full.dropna(subset=['lst']).drop(columns=['year', 'month'])
logger.info(f"Number of data points after interpolation: {len(ts_data)}")
# Out:
# WARNING:__main__:NaN values remain after interpolation, filling with nearest values
# C:\Users\user\AppData\Local\Temp\ipykernel_32552\2866831087.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ts_data_full['lst'] = ts_data_full['lst'].fillna(method='ffill').fillna(method='bfill')
# INFO:__main__:Interpolated 1 missing values
# INFO:__main__:Number of data points after interpolation: 300

# %%
# Standardize data
scaler = StandardScaler()
lst_scaled = scaler.fit_transform(ts_data['lst'].values.reshape(-1, 1)).flatten()

# %%
# Create sequences
def create_sequences(data, seq_length):
    if len(data) < seq_length:
        raise ValueError(f"Data length ({len(data)}) is less than sequence length ({seq_length})")
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# %%
seq_length = 12
X_seq, y_seq = create_sequences(lst_scaled, seq_length)
X_seq = X_seq.reshape((X_seq.shape[0], X_seq.shape[1], 1))
X_seq, y_seq = torch.FloatTensor(X_seq), torch.FloatTensor(y_seq)
logger.info(f"Number of training sequences generated: {len(X_seq)}")
# Out:
# INFO:__main__:Number of training sequences generated: 288

# %%
# Split training, validation, and test sets
train_size = int(0.7 * len(X_seq))
val_size = int(0.15 * len(X_seq))
X_train_ts, X_val_ts, X_test_ts = X_seq[:train_size], X_seq[train_size:train_size+val_size], X_seq[train_size+val_size:]
y_train_ts, y_val_ts, y_test_ts = y_seq[:train_size], y_seq[train_size:train_size+val_size], y_seq[train_size+val_size:]
logger.info(f"Training set size: {len(X_train_ts)}, Validation set size: {len(X_val_ts)}, Test set size: {len(X_test_ts)}")
# Out:
# INFO:__main__:Training set size: 201, Validation set size: 43, Test set size: 44

# %%
# Define LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, num_layers=1, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

# %%
# Train model
model = LSTMModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_dataset = TensorDataset(X_train_ts, y_train_ts)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)

num_epochs = 500
model.train()
for epoch in range(num_epochs):
    for batch_X, batch_y in train_loader:
        outputs = model(batch_X)
        loss = criterion(outputs.squeeze(), batch_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # Validation step
    model.eval()
    with torch.no_grad():
        val_outputs = model(X_val_ts)
        val_loss = criterion(val_outputs.squeeze(), y_val_ts)
    model.train()
    if (epoch + 1) % 20 == 0:
        print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}')
# Out:
# Epoch [20/500], Train Loss: 0.0897, Val Loss: 0.0448
# Epoch [40/500], Train Loss: 0.0584, Val Loss: 0.0439
# Epoch [60/500], Train Loss: 0.0520, Val Loss: 0.0376
# Epoch [80/500], Train Loss: 0.1088, Val Loss: 0.0446
# Epoch [100/500], Train Loss: 0.0700, Val Loss: 0.0450
# Epoch [120/500], Train Loss: 0.0355, Val Loss: 0.0413
# Epoch [140/500], Train Loss: 0.1075, Val Loss: 0.0292
# Epoch [160/500], Train Loss: 0.0247, Val Loss: 0.0364
# Epoch [180/500], Train Loss: 0.0342, Val Loss: 0.0364
# Epoch [200/500], Train Loss: 0.0510, Val Loss: 0.0326
# Epoch [220/500], Train Loss: 0.0269, Val Loss: 0.0371
# Epoch [240/500], Train Loss: 0.0530, Val Loss: 0.0341
# Epoch [260/500], Train Loss: 0.0515, Val Loss: 0.0323
# Epoch [280/500], Train Loss: 0.0243, Val Loss: 0.0282
# Epoch [300/500], Train Loss: 0.0123, Val Loss: 0.0261
# Epoch [320/500], Train Loss: 0.0276, Val Loss: 0.0293
# Epoch [340/500], Train Loss: 0.0356, Val Loss: 0.0293
# Epoch [360/500], Train Loss: 0.0332, Val Loss: 0.0253
# Epoch [380/500], Train Loss: 0.0314, Val Loss: 0.0265
# Epoch [400/500], Train Loss: 0.0195, Val Loss: 0.0268
# Epoch [420/500], Train Loss: 0.0171, Val Loss: 0.0248
# Epoch [440/500], Train Loss: 0.0274, Val Loss: 0.0294
# Epoch [460/500], Train Loss: 0.0157, Val Loss: 0.0273
# Epoch [480/500], Train Loss: 0.0175, Val Loss: 0.0282
# Epoch [500/500], Train Loss: 0.0357, Val Loss: 0.0231

# %%
# Evaluate model
model.eval()
with torch.no_grad():
    test_pred = model(X_test_ts).squeeze().numpy()
    test_pred_rescaled = scaler.inverse_transform(test_pred.reshape(-1, 1)).flatten()
    y_test_rescaled = scaler.inverse_transform(y_test_ts.numpy().reshape(-1, 1)).flatten()
    test_rmse = np.sqrt(mean_squared_error(y_test_rescaled, test_pred_rescaled))
    test_r2 = r2_score(y_test_rescaled, test_pred_rescaled)
    print(f'LSTM Test RMSE (after inverse scaling): {test_rmse:.2f}, R²: {test_r2:.2f}')
# Out:
# LSTM Test RMSE (after inverse scaling): 1.62, R²: 0.96

# %%
# Future prediction
future_months = 72
last_sequence = X_seq[-1].reshape(1, seq_length, 1)
future_pred = []
model.eval()
with torch.no_grad():
    current_seq = last_sequence.clone()  # Use clone() for Tensor
    for _ in range(future_months):
        pred = model(current_seq).item()
        future_pred.append(pred)
        current_seq = torch.roll(current_seq, -1, dims=1)
        current_seq[0, -1, 0] = pred

future_pred_rescaled = scaler.inverse_transform(np.array(future_pred).reshape(-1, 1)).flatten()

# Visualization with validation comparison
# Split historical data into train, validation, and test periods for plotting
train_val_dates = ts_data['datetime'].iloc[:train_size + val_size + seq_length]
train_val_lst = ts_data['lst'].iloc[:train_size + val_size + seq_length]
test_dates = ts_data['datetime'].iloc[train_size + val_size + seq_length:]
future_dates = pd.date_range(start=test_dates.iloc[-1] + pd.offsets.MonthBegin(1), periods=future_months, freq='MS')

# Plotting
plt.figure(figsize=(12, 6))
# Plot historical data (train + validation)
plt.plot(train_val_dates, train_val_lst, label='Historical LST (Train + Val)', marker='o', color='blue')
# Plot test set (actual vs predicted)
plt.plot(test_dates, y_test_rescaled, label='Actual LST (Test)', marker='o', color='green')
plt.plot(test_dates, test_pred_rescaled, label='Predicted LST (Test)', marker='x', linestyle='--', color='orange')
# Plot future predictions
plt.plot(future_dates, future_pred_rescaled, label='Predicted LST (2025-2030)', marker='x', linestyle='--', color='red')

plt.xlabel('Time', fontsize=14)
plt.ylabel('Average LST (°C)', fontsize=14)
plt.title('Shanghai LST Time Series Forecast with Validation (2000-2030)', fontsize=16)
plt.legend()
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'lstm_forecast_with_validation_2000_2030.png'), dpi=300)
plt.close()
